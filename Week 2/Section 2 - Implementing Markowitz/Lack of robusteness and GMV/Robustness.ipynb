# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import edhec_risk_kit as erk
import numpy as np
import pandas as pd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload
ind = erk.get_ind_returns()
er = erk.annualize_rets(ind["1996":"2000"],12)
cov = ind["1996":"2000"].cov() #The covariance matrix

# %%
l = ["Food","Steel"]
erk.msr(0.1, np.array([.11, .12]), cov.loc[l , l]) #A small change in expected returns, have a big impact on the weights
# Out:
# array([0.57930354, 0.42069646])

# %%
erk.msr(0.1, np.array([.10, .13]), cov.loc[l , l]) #Big problem of the sensitivity of the inputs
# Out:
# array([0., 1.])

# %%
erk.plot_ef(20, er, cov, riskfree_rate=0.1, show_ew=True, show_cml= True) #The global minimum variance need no input return
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
erk.plot_ef(20, er, cov, riskfree_rate=0.1, show_ew=True, show_cml= True, show_gmv=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sebastiencaron/Desktop/Portfolio Construction with Python/Week 2/Section 2 - Implementing Markowitz/Lack of robusteness and GMV/Robustness.ipynb Cell 6' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sebastiencaron/Desktop/Portfolio%20Construction%20with%20Python/Week%202/Section%202%20-%20Implementing%20Markowitz/Lack%20of%20robusteness%20and%20GMV/Robustness.ipynb#ch0000005?line=0'>1</a> erk.plot_ef(20, er, cov, riskfree_rate=0.1, show_ew=True, show_cml= True, show_gmv=True)
#
# File ~/Desktop/Portfolio Construction with Python/Week 2/Section 2 - Implementing Markowitz/Lack of robusteness and GMV/edhec_risk_kit.py:283, in plot_ef(n_points, er, cov, style, show_cml, riskfree_rate, show_ew, show_gmv)
#     279 ax = ef.plot.line(x="Volatility", y="Returns", style=style)
#     282 if show_gmv:
# ...
